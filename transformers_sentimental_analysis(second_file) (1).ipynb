# %% [markdown]
# Popular transformer models used for sentiment analysis include BERT, GPT, and RoBERTa. Researchers and practitioners often leverage pre-trained models released by organizations like OpenAI, Google, and others, and fine-tune them on specific sentiment analysis datasets for improved task performance. Additionally, transfer learning allows these models to generalize well to different domains and languages, making them versatile for sentiment analysis applications.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
from transformers import pipeline
sentimental_analysis = pipeline("sentiment-analysis")
data = ["she is not very good and not even beautiful"]

print(sentimental_analysis(data))
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'NEGATIVE', 'score': 0.9997904896736145}]

# %%
# optamized model

# %%
specific_model = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
specific_model(data)
# Out:
# config.json:   0%|          | 0.00/949 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/338 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# [{'label': 'NEG', 'score': 0.9768897294998169}]

# %% [markdown]
# VADER: It's important to note that VADER is a lexicon and rule-based sentiment analysis tool, and it doesn't require training on specific datasets. Instead, it relies on a pre-built lexicon of words and their associated sentiment scores, as well as rules to handle combinations of words and punctuation that convey sentiment.
#
# In Python, the nltk library provides an implementation of the VADER sentiment analysis tool, making it accessible for developers working on NLP projects.

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download Vader lexicon if not already downloaded
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
# Function to analyze sentiment of provided text using Vader
def analyze_text_sentiment_vader(text):
    sid = SentimentIntensityAnalyzer()
    sentiment_scores = sid.polarity_scores(text)

    # Determine sentiment based on compound score
    if sentiment_scores['compound'] >= 0.05:
        sentiment = "Positive"
    elif sentiment_scores['compound'] <= -0.05:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    print(f"Text: {text}")
    print(f"Sentiment: {sentiment}")

# Replace 'text_to_analyze' with your own text for analysis
text_to_analyze = 'She is not very good and not even beautiful.'
analyze_text_sentiment_vader(text_to_analyze)
# Out:
# Text: She is not very good and not even beautiful.
# Sentiment: Negative

# %% [markdown]
# Algorithm sentiment analysis

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.29.0-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Collecting importlib-metadata<7,>=1.4 (from streamlit)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.23.5)
# Requirement already satisfied: packaging<24,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (10.0.1)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.5.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.2)
# Collecting validators<1,>=0.2 (from streamlit)
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 18.3 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 33.8 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.2)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.15.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Installing collected packages: watchdog, validators, smmap, importlib-metadata, pydeck, gitdb, gitpython, streamlit
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
# Successfully installed gitdb-4.0.11 gitpython-3.1.40 importlib-metadata-6.11.0 pydeck-0.8.1b0 smmap-5.0.1 streamlit-1.29.0 validators-0.22.0 watchdog-3.0.0

# %%
# !pip install newspaper3k
# Out:
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.11.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (9.4.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0.1)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.3)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.31.0)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.6 MB/s eta 0:00:00
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.1.1-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 7.8 MB/s eta 0:00:00
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 20.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2023.11.17)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.13.1)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13538 sha256=a214ff496e9c5ddfd822e88b373df1084fdee071f2218f92fcc85ab48dbb456e
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3340 sha256=17c3bea92ab49647799d4d25e963393f0efa0b2998caf38a89d0938ac9b07cbb
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398381 sha256=c037b8821177e1f106438b845cd2705b2a9e18f6471f00b5dfb0d9c643f22185
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=cc00c852c6e7d2b376666b5c1712c4a64d6b71d7cfd4260d45cb801d3772ec03
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.11 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.1

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.1)

# %%
import pandas as pd
data = pd.read_excel("/content/Positive and Negative Word List.xlsx")

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                   0
# Negative Sense Word List     1
# Positive Sense Word List    25
# dtype: int64

# %%
negative = data["Negative Sense Word List"].dropna()
positive = data["Positive Sense Word List"].dropna()

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# Download NLTK datasets (run once)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Sample positive and negative words dataset
positive_words = positive  # Add your positive words
negative_words = negative  # Add your negative words

# %%
# Function to perform sentiment analysis
def sentiment_analysis(text):
    tokens = word_tokenize(text.lower())  # Tokenize and convert to lowercase
    tokens = [word for word in tokens if word.isalpha()]  # Remove non-alphabetic tokens
    tokens = [word for word in tokens if word not in stopwords.words('english')]  # Remove stopwords

    positive_count = sum(1 for word in tokens if word in positive_words)
    negative_count = sum(1 for word in tokens if word in negative_words)

    if positive_count > negative_count:
        return "Positive"
    elif negative_count > positive_count:
        return "Negative"
    else:
        return "Neutral"

# %%
# Example text for analysis
example_text = "she is not very good and not even beautiful"

# %%
# Perform sentiment analysis on the example text
sentiment = sentiment_analysis(example_text)
print("Sentiment:", sentiment)
# Out:
# Sentiment: Neutral

# %% [markdown]
# using emojis

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.9.0-py2.py3-none-any.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.9.0

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.nn.functional import softmax
import emoji

# Load pre-trained BERT model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)

# Example text with emojis
text = "I love this product! 😍"

# Tokenize and encode the text
inputs = tokenizer(text, return_tensors='pt', truncation=True)

# Forward pass through the model
outputs = model(**inputs)

# Get probabilities for each class (e.g., positive, negative)
probs = softmax(outputs.logits, dim=1).detach().numpy()[0]

# Interpret results
sentiment_labels = ['Negative', 'Neutral', 'Positive']
predicted_sentiment = sentiment_labels[probs.argmax()]

# Map sentiment labels to emojis
emoji_mapping = {
    'Negative': '😠',
    'Neutral': '😐',
    'Positive': '😊'
}

# Get the corresponding emoji for the predicted sentiment
predicted_emoji = emoji_mapping.get(predicted_sentiment, '')

print(f"Predicted Sentiment: {predicted_sentiment} {predicted_emoji}")
print(f"Sentiment Probabilities: {probs}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.51927173 0.48072833]

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.10/dist-packages (4.14.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.10/dist-packages (from tweepy) (2.31.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (2023.11.17)

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.nn.functional import softmax
import emoji
import pandas as pd

# Load pre-trained BERT model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)

# Example CSV file with a 'text' column
csv_file_path = '/content/tweet_data.csv'
df = pd.read_csv(csv_file_path)

# Process each text entry in the CSV file
for index, row in df.iterrows():
    # Example text with emojis
    text = row['tweet']

    # Tokenize and encode the text
    inputs = tokenizer(text, return_tensors='pt', truncation=True)

    # Forward pass through the model
    outputs = model(**inputs)

    # Get probabilities for each class (e.g., positive, negative)
    probs = softmax(outputs.logits, dim=1).detach().numpy()[0]

    # Interpret results
    sentiment_labels = ['Negative', 'Neutral', 'Positive']
    predicted_sentiment = sentiment_labels[probs.argmax()]

    # Map sentiment labels to emojis
    emoji_mapping = {
        'Negative': '😠',
        'Neutral': '😐',
        'Positive': '😊'
    }

    # Get the corresponding emoji for the predicted sentiment
    predicted_emoji = emoji_mapping.get(predicted_sentiment, '')

    print(f"Text: {text}")
    print(f"Predicted Sentiment: {predicted_sentiment} {predicted_emoji}")
    print(f"Sentiment Probabilities: {probs}")
    print("\n")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Streaming output truncated to the last 5000 lines.
# Text: @ditesh haha I'm unsure what I can deliver for Foss.my. I'm not using alot of opensource software ( Hail Adobe for being expensive  )
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32657325 0.6734268 ]
#
#
# Text: glues not coming off. it is sooo irritating
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36427847 0.6357215 ]
#
#
# Text: Cannot believe she is awake at 6AM on a tuesday. *yawn* And I had a bad dream. Bummer
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31618333 0.68381673]
#
#
# Text: @sentricmusic ...suffice to say their offer was ignored. Then EMI.com launched and they all laughed rather a lot...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31009197 0.689908  ]
#
#
# Text: feeling low today
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41562364 0.58437634]
#
#
# Text: Bored&amp;tired. Miss the stay-back time
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37026778 0.62973225]
#
#
# Text: It rains heeaaavily outside and i trap in this building cant go home
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32199463 0.6780054 ]
#
#
# Text: @dilyswei thank you! i know its not over but the fact that i studied day and night made me sad
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36651406 0.6334859 ]
#
#
# Text: Didn't even want to get up for work this morning. I just wasn't feeling it, but had to anyway.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32277635 0.6772236 ]
#
#
# Text: Wtf!? They still dont have britney for the record up yet.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32788873 0.6721112 ]
#
#
# Text: @chhavi Working, working, working.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3389858  0.66101426]
#
#
# Text: is suffering with the lugholes again
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32141897 0.67858106]
#
#
# Text: Someone in ROMANIA didn't like Mystic Myre http://www.smartestgames.com/gotd.php
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3318893  0.66811067]
#
#
# Text: gotta stop turning in homework late, would be gettin an A in Information Systems if it wasnt for the few late assigments
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29699805 0.703002  ]
#
#
# Text: I want my cereal! But we're out of milk
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34901214 0.6509879 ]
#
#
# Text: Oh no! Free car park I always use is now Pay &amp; Display. But I have no change
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31722906 0.6827709 ]
#
#
# Text: @zenojones I can't go to sleep... Too much to do, too little time  long week ahead of me! And ok I'll get u hat lol
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34922487 0.65077513]
#
#
# Text: Just booted into Windows to upload something since Internet is even worse under Ubuntu
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4015388 0.5984612]
#
#
# Text: was playing around putting in random twitter usernames. so many wasted blanks!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29928604 0.700714  ]
#
#
# Text: I totally just lied about going on a trip to get out of hanging out with someone. 'Airport' was the only excuse that came to mind.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31127834 0.68872166]
#
#
# Text: @whatdamnnick well, the problem with rain here is that it comes with extreme coldness.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33063236 0.6693676 ]
#
#
# Text: NBCNews reporting Pres Chief Econ guy #Summers is loaded with Wall Street money (8mil from a HedgeFund) from banks that were bailed out
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34143293 0.65856713]
#
#
# Text: @tommcfly have fun tom, i need to buy eclipse too but i have no money. sad timess
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31637892 0.68362105]
#
#
# Text: has to wait a WEEK to find out if her writing is any good  sux!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33717856 0.6628214 ]
#
#
# Text: (yay! SJ will be on come to play. Kibum is of course missing and so is Teuk  )
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34222865 0.65777135]
#
#
# Text: @wellreadkitty oh poor thing  I used ot love squeezing out the pus when I was a vet nurse. kinda gross really...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3303018  0.66969824]
#
#
# Text: &quot;Who is your favorite vintage designer?&quot; Lucy: &quot;Topshop.&quot; I miss cycle 3 of britain's ntm.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31112802 0.688872  ]
#
#
# Text: @darenzia  assuming i wont get to see u before u leave...i'll miss u punkin : *
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40562725 0.59437275]
#
#
# Text: I wanna go home!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4307203  0.56927973]
#
#
# Text: Testing twitter mobile SMS from Australia (expensive  )
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34490818 0.6550918 ]
#
#
# Text: whatchiing commercial breakdwon lol and havee homework to do  enrtertain meee
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36574122 0.6342588 ]
#
#
# Text: @Plip Would love to try Trillian Astra, but it's a closed beta and they won't let me in
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3557982 0.6442017]
#
#
# Text: @Tittch I'll second Andrew's suggestion. They might fit you in as an emergency. Chin up. Thinking of you.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28339964 0.7166004 ]
#
#
# Text: poor ando. he just got shot
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3563555 0.6436446]
#
#
# Text: sitting at my desk eating dinner. Great Thai but a bit of a sad situation overall
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28039426 0.7196058 ]
#
#
# Text: @moreshannon he isn't here!  he is down south for 2 days working!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36361897 0.63638103]
#
#
# Text: #mmuk09 Moodle 1.x must upgrade to 1.9 before being upgraded to 2.0 - Themes will probably break though
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33576074 0.6642393 ]
#
#
# Text: @Rooxxy I've got tonnes over here. Going to have to donate some I think!  I just can't eat any more!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.311067 0.688933]
#
#
# Text: @TomFelton Late nights suckkk!  Gym always makes me feel better though!! Photoshoot for what?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35080826 0.64919174]
#
#
# Text: That overnight screwed up my sleep.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37720641 0.6227936 ]
#
#
# Text: @ALEXRUSSIN Lucky, I missed it
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3649213 0.6350787]
#
#
# Text: Been with O2 for 18 months now. In need of phone upgrade. iPhone comes to ï¿½500+ over contract life  Need smartphone with cheapo talk plan!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31484488 0.6851551 ]
#
#
# Text: @paulriggall Me too  Why am I not going to Glasto?! Stupid girl! Crosby, Stills &amp; Nash are playing too!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3032914 0.6967086]
#
#
# Text: @NuJurzyBoricua I wanna go back home and go to bed.  lol whatcha workin out today?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35623205 0.64376795]
#
#
# Text: @Honey_ It's nasty.   No reports of flooding as yet. Multiple reports of bad hair and wet pants however.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29914424 0.7008558 ]
#
#
# Text: @rustyrockets Its not my birtday something went wrong please reply or I feel you dont love me
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41578433 0.5842157 ]
#
#
# Text: Mums soup made my stomach make nasty noises
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37450555 0.6254944 ]
#
#
# Text: laptop is running out of battery
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2933534  0.70664656]
#
#
# Text: worried about furry sun who has bad tartar on teeth and needs dental treatment
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3064284 0.6935716]
#
#
# Text: Finally! Fellow Ninjas logging into the forum ;) If you've done so recently can you redo again... as it woz a bit broken before
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.338496   0.66150403]
#
#
# Text: ughhhhhhhhhh twitter is bing sooooo retarded
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4083956  0.59160435]
#
#
# Text: @nickynocky I'm looking for other utility suppliers tonite now
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3754814  0.62451863]
#
#
# Text: @whykay It's lashing down here.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30985308 0.6901469 ]
#
#
# Text: chocolate covered strawberries and cottage cheese, you have defeated me
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38836572 0.61163425]
#
#
# Text: I really need to go to a dentist.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33237273 0.6676272 ]
#
#
# Text: @mfarnsworth You and I will both be retired by the time this is all done mate..
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32962006 0.67038   ]
#
#
# Text: A long flight is made even longer by a seat that won't recline. Off the red eye and grumpy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34476852 0.65523154]
#
#
# Text: @absolutelybatty *HUGS BACK* Thanks hon.  I can't believe he's gone!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32071006 0.6792899 ]
#
#
# Text: just got a tennis top in the post but i don't like it and its too big! shame
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33770686 0.6622932 ]
#
#
# Text: only 1/2day later and ants have eaten clean its bones..that poor little gecko skeleton..so very disturbing. i regret not mercy killing...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32414058 0.6758594 ]
#
#
# Text: Man today is going sooooo slowly today
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40440097 0.59559906]
#
#
# Text: wishing i was 5 again
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41653407 0.58346593]
#
#
# Text: why do i have to go to the sitty job more often than the nice one
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.46321455 0.5367854 ]
#
#
# Text: http://twitpic.com/2y8lt - I feel so bad for the band right now
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29926714 0.7007329 ]
#
#
# Text: @JonnyPotter The Simpsons on demand thing doesn't work in the UK
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4189399 0.5810601]
#
#
# Text: I don't feel like revision.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3572112  0.64278877]
#
#
# Text: awake  spanish test to make up this morning.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33957377 0.66042626]
#
#
# Text: dotnetnuke.com is down   Server Error in '/' Application.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3955695 0.6044305]
#
#
# Text: Archiving project files to SharePoint. This is not fun
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34803292 0.65196705]
#
#
# Text: Another set of iPod earbuds dying - left going quiet  Apple charge GBP20 for replacements. Better options at around that price point?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36861873 0.6313813 ]
#
#
# Text: im having a miley nite!!!!!! no sleeping boo
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40997759 0.5900224 ]
#
#
# Text: Wow! I just did 5 suicides in a row. FYI: unless you're a professional athlete...you shouldn't do suicides.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33690467 0.6630953 ]
#
#
# Text: @themaccabees I've ordered that special 7inch set thingy from that place online (I'm so forgetful) but it's still not here  i want iiiit
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3736182 0.6263818]
#
#
# Text: I have decided my room needs to be more 'quirky', so Angel gave me a mirror! And my 'a' button isn't working too well either
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3569451  0.64305496]
#
#
# Text: urghhhhhh tired  i need a proper lie in :|
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35487357 0.6451264 ]
#
#
# Text: Dindle Manksniff Foods Corp. founder Dindle Manksniff disappears on midnight trip to fridge, presumed dead
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31000137 0.6899986 ]
#
#
# Text: mandy moore &quot;cry&quot; ? http://twt.fm/33009 - &quot;a walk to remember&quot; by far my favorite movie, so sad i cried like a baby
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30543172 0.6945683 ]
#
#
# Text: @LgHague Just uni, ruining my life as per usual
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37463874 0.6253612 ]
#
#
# Text: why isn't the hills available online yet?? soo disappointing
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2951681 0.7048319]
#
#
# Text: @nikkiwoods Exactamundo!!! For some reason I think Foxx is knocked out, so IDK what's gonna happen, sorry
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32330915 0.6766908 ]
#
#
# Text: the poor  spartans
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40570614 0.59429383]
#
#
# Text: I'm bored. Sun it's not present in a sky  . I deppressed so much! I want see the SUN...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3222345 0.6777655]
#
#
# Text: My night; went to the bar, Felt up a marred woman, went home hard and alone
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3366169 0.6633831]
#
#
# Text: That IIS-Crash is a tough nut   Posted to newsgroup: http://is.gd/raIp
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38639054 0.61360955]
#
#
# Text: bah, immune system finally gave in. It did so well this year....  Throat is feeling horrid now.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32622513 0.67377484]
#
#
# Text: crappy day so far.  whyyyyy?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.315298 0.684702]
#
#
# Text: @BeththePQ your blog won't let me comment again!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3849074 0.6150926]
#
#
# Text: my teef hurt
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.46991253 0.5300874 ]
#
#
# Text: I have headache
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40252024 0.5974798 ]
#
#
# Text: @adamcurry can I get download version of the Dvorak Interlude... since streaming is banned at work...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32834968 0.6716503 ]
#
#
# Text: @wwwicked I think I have tried everything but feel free to try to crack it, I am at a loss
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30989352 0.6901065 ]
#
#
# Text: Well that was a waste of time
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.45714974 0.54285026]
#
#
# Text: #i36 Hope I'm feeling better by thursday, will be seriously annoyed if I'm ill over LAN
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3451482 0.6548518]
#
#
# Text: Back from Bangalore, Missed dancing with a handsome wonderfully smiling foreigner
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.262209   0.73779094]
#
#
# Text: now i have to do my stupid italian homework
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41385752 0.5861424 ]
#
#
# Text: cant be bothered 2 get out of bed 2day - feelin ultra lazy!  i miss josh
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30822328 0.6917767 ]
#
#
# Text: coffee time - wish i had whiskey like @cameronreilly
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3998956  0.60010433]
#
#
# Text: i really want to play singstar! but all my singstar discs are scratched
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37412372 0.62587625]
#
#
# Text: @mileycyrus ouch mine too
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.46675068 0.53324926]
#
#
# Text: I didn't see that many cherry blossoms this year
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3943926 0.6056074]
#
#
# Text: ARGH!!! iggy pop swift cover add on #spotify way to kill the mood
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.39314872 0.6068513 ]
#
#
# Text: Arse, totally forgot about a webinar that I wanted to attend this morning. Now I'll never know how to secure virtualised environments
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32729828 0.6727017 ]
#
#
# Text: is going to the tenancy tribunal tomorrow  Try to get my bond back
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36675254 0.6332475 ]
#
#
# Text: @Emmavieceli aw no  Get better soon! Have honey and lemon drinks!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31744054 0.6825595 ]
#
#
# Text: ugh does anyone know what i can do to stop anxiety attacks? pleeease...i need help
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32264695 0.6773531 ]
#
#
# Text: @cupcakesfortwo no pain to really be the issue though, there's the thing.. can't figure it out...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.334448 0.665552]
#
#
# Text: at degool cafe waiting the clock to be 2pm
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31180882 0.6881911 ]
#
#
# Text: I am feeling sick
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40196353 0.59803647]
#
#
# Text: This will have to do, I lost the password to the version without the _
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3886631 0.6113369]
#
#
# Text: Fuck. I feel a hell of a lot worse today
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34940532 0.6505947 ]
#
#
# Text: In France, Today it's raining
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34777692 0.65222305]
#
#
# Text: ufffffffffffffffff, ke gorom!!!! need to a pond to swim
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35536903 0.644631  ]
#
#
# Text: seekin'for a new job..
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29068226 0.70931774]
#
#
# Text: 5 hours sleep in 4 days and still working on my birthday
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31763637 0.6823636 ]
#
#
# Text: @juanpol That page doesn't exist!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37006027 0.6299398 ]
#
#
# Text: @ammarz I could not install it for XP users here in Aramco, Vista users have no problem, weird
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32673335 0.67326665]
#
#
# Text: @Seamonkey86 I am on a healthy eating kick! I could only have shetland pony.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34684354 0.6531564 ]
#
#
# Text: Did not sleep well at all, and have a very unhappy stomach.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2685303  0.73146963]
#
#
# Text: is hanging out washing
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3788474 0.6211526]
#
#
# Text: bout to take my dog for a walk kinda tired aswell went training this morning
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3614185 0.6385815]
#
#
# Text: skooool   i hope for some reason it is SOOO MUCH fun, and like the best.  hehe
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34259635 0.6574036 ]
#
#
# Text: @bradiewebbstack aww poor bradie  stuff those vegies! Take a stand!!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34597623 0.65402377]
#
#
# Text: @vickybeeching saw someone at the apple store told that their warranty was voided cuz they unlocked their phone.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38643852 0.6135614 ]
#
#
# Text: up, and throat still hurts
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3954168 0.6045832]
#
#
# Text: italian lesson now! Bored!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40684354 0.5931564 ]
#
#
# Text: ooooooooooooh my headddd  uncle johnny i never should have agreed to work the town election for you when I got that drunk last night....ow
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.301852 0.698148]
#
#
# Text: @shedfire MrsShedfire been taking pictures of you without your shirt?  Bleeeech!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32025564 0.67974436]
#
#
# Text: @cuprohastes Don't feed cars Milky Ways though - they don't like it. That advert was very misleading - breaking down on the A14 isn't fun
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38198775 0.61801225]
#
#
# Text: @johnnybeane me too... I'll see on Amazon uk.. otherwise they make me pay custom tax if I order it from the US
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38281822 0.61718184]
#
#
# Text: NZ the place to be! Miss my own bed a bit though
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41068313 0.58931684]
#
#
# Text: just read R#42's amazing blog. so tired  don't want to go to school tomorrow either. hmmph
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30929548 0.6907045 ]
#
#
# Text: i hate being awake!  going to school, western civ presentation andn a really awesome lunch.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32492852 0.67507154]
#
#
# Text: has just discovered the downside of going away for the weekend - the food shopping still needs done
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36741742 0.6325826 ]
#
#
# Text: @_ophelia Haha, sorreh.  I tries 2 spek normalz now k?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3564385 0.6435615]
#
#
# Text: is that snow?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35939285 0.6406072 ]
#
#
# Text: moulin rouge mad me cry!! once again!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34353432 0.6564657 ]
#
#
# Text: Trying to Shout but can't find people on the list
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.46424863 0.5357514 ]
#
#
# Text: ughh can't find my red sox hat, gotta wear this creepy nick pirro version
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33011174 0.66988826]
#
#
# Text: slept wonderfully- finally.  tried swatching for new project (Classic lines cardi) from stash but don't like colors  must wait for now...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31379166 0.6862083 ]
#
#
# Text: ARGH why did the linux people have to call their task scheduler &quot;at&quot;? Makes it impossible to search for help with
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3846378 0.6153621]
#
#
# Text: A bit tired of the 24/7 cribfest that surrounds me  #fb
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38117015 0.6188299 ]
#
#
# Text: Sigh. Am sitting here working with my leg propped up.  It's making my ankle feel better but also making my knee hurt
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31432715 0.6856728 ]
#
#
# Text: @Rammi I love Chinatown and its cheap stuffs, but I hardly communicate with the sellers, they can't speak English
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32677355 0.6732264 ]
#
#
# Text: been rather tempted by a Premier Projector on eBay...  But then thought that a fifth drumkit might be a bit excessive...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29470605 0.705294  ]
#
#
# Text: @tsisey no i wasnt there, really wanted to go though
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30180317 0.6981968 ]
#
#
# Text: Up &amp; don't feel like running   why am I so lazy!!!???
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3330405 0.6669595]
#
#
# Text: @loudmouthman yeah, I even turned off rules and spam blocking
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36744785 0.63255215]
#
#
# Text: @AlexJReid - nice of it to inform you during the install, eh? Silly Msoft. It works on the Intel Mac but not my G5  shame, it's quite cool
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3757328 0.6242672]
#
#
# Text: @sophiebenjamin That's disappointing, SCIENCE was golden
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36819032 0.6318097 ]
#
#
# Text: want to see P!nk again
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31432927 0.6856708 ]
#
#
# Text: @tinchystryder me and my mates waited 2 hours for you last night and you just walked past !  dissapointed tinchy...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35752395 0.642476  ]
#
#
# Text: @Vicki_Owen I used it for undergrad dissertation many years ago but haven't used it since.Recall hating it but think I need to use again!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30635956 0.69364053]
#
#
# Text: @rachaelsmart doesnt everyone, exams are so close too. It sucks
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33194435 0.6680556 ]
#
#
# Text: Levi- Good morning cruel world. Why does 6am have to come so early??? WHY???
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32774568 0.67225426]
#
#
# Text: Sucks hard that Roundhay has been cancelled  I was reet lookin forward to a day out
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34126645 0.65873355]
#
#
# Text: working on words next to the friendly AIR install button to reassure user that scary install dialog is ok (certificate is not enough)
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3879639 0.6120361]
#
#
# Text: @alesa13 nothing new here, same old boring crap  but at least theres sunshine...and tequila!  whats new with u?? have fun :*
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3544744  0.64552563]
#
#
# Text: Still having problems with the iPod   Disk is storing data out of order &amp; I keep getting a disk error...my entire life in music...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3267232 0.6732768]
#
#
# Text: feeling stressed about my little dog who looks like he has spinal injuries
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38960668 0.61039335]
#
#
# Text: grrr my tv signal is really bad! its not even picking up one single channel
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34636867 0.6536313 ]
#
#
# Text: really need to do something. watched one to many hannah montanna's
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3304621 0.6695379]
#
#
# Text: @chrisgedrim You dissed my taste in music
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.43585688 0.5641431 ]
#
#
# Text: @nevaneva I find Ekitan doesn't give the best results for a lot of searches, especially to/from airports
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32876927 0.67123073]
#
#
# Text: @pinknantucket strangely, no
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35265198 0.647348  ]
#
#
# Text: has nothing to do today.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31911555 0.6808844 ]
#
#
# Text: @siximpossible yes, it was Easter Chocolate - i'm a sucker for a hollow egg, and there was this discount store and ....
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33657584 0.6634242 ]
#
#
# Text: i want to go on holiday
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.42162848 0.5783715 ]
#
#
# Text: @ChrisBaccam I just generally have a crappy day at work today. Ever been stuck in a job you used to love but now hate? Its not nice
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31581724 0.68418276]
#
#
# Text: Difficulties with GTalk  Closing the Division for the day. Later, everyone.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32296786 0.6770321 ]
#
#
# Text: is knackered after working nights
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3490191  0.65098095]
#
#
# Text: 8 page essay
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34480533 0.65519464]
#
#
# Text: ARGH! GEESE ATTACK!!!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37622163 0.6237784 ]
#
#
# Text: Migraines are not fun.. I wanna cry
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34265283 0.65734714]
#
#
# Text: @tylerwalters  lo siento. You're not the only one tonight, if it's any consolation.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28098562 0.71901435]
#
#
# Text: Bbutton ring fell off  needa replace one asap
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37439004 0.62561   ]
#
#
# Text: who is working over the holidays?? i am!!!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36858985 0.6314102 ]
#
#
# Text: @jeorgina Aww, Georgie!  Those boots sound killer though. XD
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32523748 0.6747625 ]
#
#
# Text: @forfolkssake Not only is a reply to that email imminent, but also -shock!- that second review that was due yesterday. Housebound is bad
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37366858 0.6263314 ]
#
#
# Text: Haha, I'm sooo bored.... Friends are great aren't they? Oh I broke my TV...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3230336 0.6769664]
#
#
# Text: @PamJH yes, more than 150 people killed and a lot missing
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3516781 0.648322 ]
#
#
# Text: I accidentally cut some of my hair
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4378801  0.56211984]
#
#
# Text: @karmadillo No - bad - very bad  Not bought a single Easter Egg yet so in family bad books and dog is missing his extra long walks.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37398544 0.6260145 ]
#
#
# Text: wish i was going to melbourne this wkend for harlot house at tramp!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3978293 0.6021707]
#
#
# Text: gah... it wont let me make a myspace for my social studies campaign...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.320631   0.67936903]
#
#
# Text: Is still wondering how he managed to lose at golf to Dan last night - throwing away a 7 shot lead after the front 9!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35315296 0.646847  ]
#
#
# Text: @trainhitsboy excellent taste as ever and perfect context.  I've never covered a Cure song in public  but have the Scorpions. sick.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3211178 0.6788822]
#
#
# Text: it is not that hot outside today
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35150537 0.6484946 ]
#
#
# Text: @flurogoddess i would hope that most agree with you there. a worringly long day  hope all goes in your favour x
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32902816 0.6709718 ]
#
#
# Text: Struck down with viral infection, peaved getting ill.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32021055 0.6797895 ]
#
#
# Text: More boring job hunting..
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30545244 0.6945476 ]
#
#
# Text: @Nicolawills13 is the chat on line yet? now not on freeview not good
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4009393 0.5990607]
#
#
# Text: @yasminkaye Do it!! Don't be grumpy though, that makes the internet a sad panda
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4065139  0.59348613]
#
#
# Text: has got back from her driving lesson and is now waiting to go do some revision
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3453946 0.6546054]
#
#
# Text: I am sooo tired and soooo guilty
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.337518   0.66248196]
#
#
# Text: is at shisha with NJ and Syarif. heheheheh. using Syarif's new laptop. LOL budak poly
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2945708  0.70542914]
#
#
# Text: @andyclemmensen  lol i know i hate old computers  they suck big time! :p
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.43354177 0.5664583 ]
#
#
# Text: @Nappytabs aaaaah im insanely annoyed at the fact that i didnt get to meet you  and i wanted it to be my birthday wishhh. ahah awwwwwww.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31748104 0.68251896]
#
#
# Text: has a cold
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40264815 0.5973518 ]
#
#
# Text: bored. sam cant come over
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28856763 0.7114324 ]
#
#
# Text: @wgrzmarissa / Great. That'll make for a long adventurous commute!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32116234 0.67883766]
#
#
# Text: Gee, 4 1/2 hours of sleep is definitely not enough. It's going to be another tough day.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3414883 0.6585117]
#
#
# Text: @RobertCastley can't quite see 'em from Barclaycard
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41393116 0.58606887]
#
#
# Text: is a single lady
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38784483 0.6121552 ]
#
#
# Text: boredd need 2 get redy soon cba tho
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5478681  0.45213193]
#
#
# Text: No 12-hour coma today. I had a nightmare that shook me awake.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31667945 0.6833206 ]
#
#
# Text: @mesteras guess I can't ask you to help me find blue contacts then
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38454637 0.61545366]
#
#
# Text: @QueenSerena1 just keep trying to upload it babe... it will upload...sometimes you need to try at least a dozen times..i know
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.339219   0.66078097]
#
#
# Text: @Sixxjohn I'm the worst I know  but I'll be back soon
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34983265 0.65016735]
#
#
# Text: Missing the football tonight due to work. Not looking forward to later.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30018926 0.6998108 ]
#
#
# Text: Ugh, I need a bigger ipod. Like seriously
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34128395 0.6587161 ]
#
#
# Text: @iCoopers You tease  But thank you
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3489638 0.6510362]
#
#
# Text: NAB didn't pass on the cut. I wonder what ANZ will do now.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38262528 0.6173747 ]
#
#
# Text: @westy154 Me too   I don't do suits.  I look like I'm in fancy dress.  Especially with shoulder pads.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.346483 0.653517]
#
#
# Text: Nambu getting some good reviews as an alternative to TweetDeck - sadly Mac only
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32541063 0.6745894 ]
#
#
# Text: @pgreenbe I agree. But I hope u'll pardon my technology colored glasses while I learn the ropes of mgmt &amp; strategy.  It was top of mind
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.374004 0.625996]
#
#
# Text: 12:20 i don't know what to do
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35607705 0.6439229 ]
#
#
# Text: Postponing my trip to Kenya. G/F going to TZ for training for a few weeks
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28490415 0.7150959 ]
#
#
# Text: Very concerned to see cyclist had been knocked off bike at bottom of North Walls.   Very much hope they will be OK.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29645145 0.70354855]
#
#
# Text: Fellow Philip Glass lovers, have you seen  this? (+ he's in concert @ Miami U next Wed but I'm  speaking somewhere   http://bit.ly/9BdqX
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3619848 0.6380152]
#
#
# Text: awake...cannot go back 2 sleep &amp; its still snowing outside....wondering am i going 2 b able 2 go n e where 2day
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3431306 0.6568694]
#
#
# Text: @africana oh noooo  i hope you're ok, what did you eat? &lt;3333
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3405987 0.6594013]
#
#
# Text: @dailycomplainer    I'm sorry... if I didn't have to pay 450 for rent I would be going lameeeeee
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3487288  0.65127116]
#
#
# Text: I bought an iPhone 3g off eBay like 2weeks ago, still hasn't come
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29421958 0.7057804 ]
#
#
# Text: @PD78 I was being nice. Poor you....hope you feel better soon
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3250423 0.6749577]
#
#
# Text: @tbrd damn it, Craig can;t make it
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3507904 0.6492096]
#
#
# Text: I'm too sick from my meds to even stand  FML
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.45488113 0.54511887]
#
#
# Text: @marshmallowpie luckily not, lot of devastation there, very bad situation
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3403979  0.65960205]
#
#
# Text: @CassieFX You a lost cause girl  ;)
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38879192 0.611208  ]
#
#
# Text: @Tittch Big hugs, I hope everything goes peacefully
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32130733 0.6786927 ]
#
#
# Text: Ack everybody's talking about Krispy Kreme. And I have a tooth ache right now.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3716268 0.6283732]
#
#
# Text: Dinner was gross. Took forever and tasted like dog food. It was probably nice, but i hate food.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37167305 0.6283269 ]
#
#
# Text: Fuxing homework
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41739962 0.5826004 ]
#
#
# Text: @HarrietPenguin Very jealous! Seeing him later this year at MEN but won't be the same as a little gig
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.42260846 0.5773915 ]
#
#
# Text:  AFI are not at reading til sunday this sucks !!!!!!!!!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34071526 0.65928483]
#
#
# Text: @EmeraldDiscount That's fine. Not sure about forecast though
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3208021  0.67919797]
#
#
# Text: @avalanchelynn habanero.... hot hot hot.... hard to find here in Australia
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34997183 0.65002817]
#
#
# Text: what to do
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31952268 0.6804774 ]
#
#
# Text: I hate coming in early, throws me right out with lunch. Been hungry for the past two hours - 40 minutes still to go.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30872196 0.69127804]
#
#
# Text: mmmm chocolate cupcake.... This is all Lorraine Kelly's fault you know, her and her cakestand full of cupcakes.. I'm getting hooked
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3551058  0.64489424]
#
#
# Text: @edibow haha, I have snot power too......1 week and counting!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3634794  0.63652056]
#
#
# Text: Whats up with the world? why do ppl decide to shoot others?  watching the news is so depressing
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33003408 0.66996586]
#
#
# Text: @Ayla_F I'm not so sure anymore
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34873077 0.6512692 ]
#
#
# Text: @doqtu84 too much flash, and the guestbook is outdated
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34414953 0.65585047]
#
#
# Text: too many updates on twitter... not able to follow everything
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31850642 0.6814936 ]
#
#
# Text: I am in a situation to write internals, but will have to write DMW
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33435512 0.6656449 ]
#
#
# Text: want to go into town but don't really feel like walking down their on my own
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32440943 0.6755906 ]
#
#
# Text: Got a really bad throat  Gonna see if we've got any yoghurt in.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.330142 0.669858]
#
#
# Text: @LPetersson pls pls PHOTOS!  Iï¿½m not gonna sign up to Facebook just to see photos.  Put them on Flickr or something!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32165948 0.67834055]
#
#
# Text: Good morning at work  don't wanna be there fuckit another day another dollar!!!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3200291 0.6799709]
#
#
# Text: @mokshjuneja  A good movie (premier) would cheer me up!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35886475 0.6411352 ]
#
#
# Text: @DonnaNBC4 there were actually 2 blankets.  Out of control!  Poor guy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35228208 0.64771795]
#
#
# Text: has a bad head
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3162158 0.6837842]
#
#
# Text: @ZeenaV Sims 2 shut down on me again.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3797807  0.62021935]
#
#
# Text: @spaulds1 Hey , I'm good thanks , just had lunch  hehe , it's noon overhere ( Belgium ) and it's raining
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38090435 0.6190956 ]
#
#
# Text: @fallbrooke Eric, get a twitter! Lol and sorry about your teeth...  why are you getting them out? Dentists will do anything for money....
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32507578 0.6749242 ]
#
#
# Text: my thoughts and prayers go out to the people affected in the earthquake, Italy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2972248 0.7027752]
#
#
# Text: I heard somebody is going to be killed off of CSI NY!!! NOOOOOO  so sad
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36993402 0.630066  ]
#
#
# Text: eating cold dinner
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41762176 0.5823782 ]
#
#
# Text: @philipjohn I know what you mean, we didn't have the drop down to start with, but were getting complaints. I can't win
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32410327 0.67589676]
#
#
# Text: @Schofe I feel so sorry for the women that lost her husband to those disgusting thugs! Hearing her story made me cry
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35467476 0.6453253 ]
#
#
# Text: gets kinda annoyed for no apparent reason  off to do some religion homework, then some english D:
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36216006 0.6378399 ]
#
#
# Text: STILL reconcilling bloody key deposits,craving hot beaches, and blue sea's my baby and me sitting under palm tree's! Not gonna happen!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30487597 0.69512403]
#
#
# Text: I'm not in mood+situation to write internals but will have to write DMW tomo
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3353723  0.66462773]
#
#
# Text: @BigB3n lots of imitations too!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38779506 0.61220497]
#
#
# Text: @MagicBartender Heya. Aww I missed PS. I didnt see your tweet until now.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3247343  0.67526567]
#
#
# Text: @weblivz What a boot. I would have demanded one stinking scone from her mighty haul
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36915016 0.63084984]
#
#
# Text: its morning. way too early. way too little sleep. really dragging myself to the gym, and I don't have my mp3 player. this is gonna suck.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32125086 0.67874914]
#
#
# Text: @heidimontag can't wait for your album.. yay! but i want it now  when will it be out ?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32480475 0.6751952 ]
#
#
# Text: following some twitter accounts that report on earthquakes. situation in Abruzzo, Italy, is not good.180 dead. photos http://ow.ly/2fRj
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2920628  0.70793724]
#
#
# Text: i need a better tweet from russ, mine was just an answer to a question and not ACTUAL love
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3805877 0.6194123]
#
#
# Text: Got to get appointment for ultrasound  Doc didnt pick up on it until blood tests as normally prob for obese peeps....and well Im not.....
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3221784 0.6778216]
#
#
# Text: is job hunting again... dont want to but i'm too unhappy at work. been there too long n need to leave n do something i enjoy.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31859925 0.6814007 ]
#
#
# Text: Oh no the weather has turned bad. 3m seas predicted for tomorrow. This could cause a real problem  hopefully the prediction is wrong
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2969708  0.70302916]
#
#
# Text: I am responsible for extreme tree murder
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4594851 0.5405149]
#
#
# Text: off to go play some badminton, then walk grandads dog, then back to revising!!!!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3192684  0.68073153]
#
#
# Text: @KankzXD My headphones died  I miss them. Earphones are just not good enough!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31900755 0.6809924 ]
#
#
# Text: the retr bar quiz is hilarious. done it twice and come last both times  the guy from behind the bar gave me his number!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35964665 0.64035344]
#
#
# Text: @Shadez err the storm has ended. not sure who's been devastated more
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32113507 0.67886496]
#
#
# Text: @quartzgirl6 go to bed, I wish I could, I'm still at work
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30377215 0.6962278 ]
#
#
# Text: work is like PULLING TEETH today
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.50228935 0.4977107 ]
#
#
# Text: @bradiewebbstack haha damn you now i want jelly beans
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4490193 0.5509807]
#
#
# Text: Why is everything biting me?  First the hamster, now the cat
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34301215 0.6569879 ]
#
#
# Text: Can't use Twitter with my phone
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36759183 0.6324082 ]
#
#
# Text: @lucy_moore93 HaHAH lol, ignoring definately does not work.. cause they end up jus pissingannoying u more, well ive found that anyway
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37558895 0.62441105]
#
#
# Text: It's depressing to start your day knowing you're not coming home until tomorrow night.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37225878 0.6277413 ]
#
#
# Text: Day is frantic - being shotgunned with lots of work requests all at the same time - running out of hands
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36555934 0.63444066]
#
#
# Text: I have had 2 days of TV control, and there is damn near nothing worth watching
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3167105  0.68328947]
#
#
# Text: @mellalicious haha no, she isn't here unfortunately  this is the one person in the house who isn't cool.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32837057 0.6716294 ]
#
#
# Text: @miketually @DanLees  I wish people would stop doing stupid things like that! I leave mine on 365, I guess that proves the opposite
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40981224 0.5901878 ]
#
#
# Text: Seriously beginning to hate this entire 'get up and write' routine. Wish the essays could all just be over with
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30147874 0.69852126]
#
#
# Text: @jobeaz damn, sorry I missed it... But I'll be in Brisbane until Thursday night
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34429646 0.65570354]
#
#
# Text: P.s. @MichaelHenry hosed me down with gasoline
# Predicted Sentiment: Neutral 😐
# ...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.387676   0.61232406]
#
#
# Text: Off to The lumberyard
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3085103 0.6914897]
#
#
# Text: thinks the numbing is getting worse!! and fillings are much worse than I remember... does anyone want 7 easter eggs???!  xx
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32073146 0.67926854]
#
#
# Text: I'm pretty sure I have a small cold...ugh baby germs
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37797967 0.62202036]
#
#
# Text: starting a short lunch break. must be short. my paper is not as far as it was planned to be at this time of day
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32626575 0.6737342 ]
#
#
# Text: waiting to go back to my cold, lonely student room !  booo.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3207599 0.6792401]
#
#
# Text: @iamjonathancook have fun tonight. I wish i could gooooo
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32780805 0.672192  ]
#
#
# Text: @weirdchina I hope you realize that your website is blocked by China.. I live in Wuhan and have to proxy in to your site
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32517081 0.6748292 ]
#
#
# Text: @j_e_p  me too
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37129617 0.62870383]
#
#
# Text: http://twitpic.com/2ya1c - Good F'in Morning  Springtime my ass. Global warming?! Suck it!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32964587 0.6703541 ]
#
#
# Text: @mileycyrus Aww  Chin up hun! You can do it
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36724195 0.6327581 ]
#
#
# Text: CBI is Congress Bureau of Investigation. ...Ita a BIG RED QUESTION MARK on the capability of Indian Judiciary System...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2889128 0.7110872]
#
#
# Text: My Lumiquest Softbox III arrived! But all the batteries in my SB-800 are dead
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33070993 0.66929007]
#
#
# Text: Thinks!!!!!! i should have rented wheelman
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.40421903 0.59578097]
#
#
# Text: Off to the office again today - going to be a BUSY day  So many things to do.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30124184 0.6987581 ]
#
#
# Text: Eating one of the kids' Easter Eggs  Oh dear, I have no will power ......
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3432401 0.6567599]
#
#
# Text: my cat died last january- he was one of my best friends
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33386004 0.6661399 ]
#
#
# Text: Oh and forgot to mention. I have no voice.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33898097 0.661019  ]
#
#
# Text: @miafreedman I'm loving Harem pants at the moment! Seriously! But not the ones with a crutch to the knee! Ewwww
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37735716 0.6226428 ]
#
#
# Text: is soo bored and  i just wanna go out and have some fun but thandis at some gay thing all day
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37649593 0.6235041 ]
#
#
# Text: @ollyog I really am jealous
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.45533052 0.5446695 ]
#
#
# Text: okay off to do some job hunting.. can you believe a small gaming comp told me I was over qualified with experience &gt;.&lt; for real  ninnies
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36568865 0.6343114 ]
#
#
# Text: Saracens losing Andy Farrell to retirement
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3090528  0.69094723]
#
#
# Text: bad dayy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38032335 0.6196767 ]
#
#
# Text: is gutted my M.AC myth Lipstick broke after 1 use
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.39360067 0.6063993 ]
#
#
# Text: @JodieWanKenobie Oh yer btw before i go i direct messaged you  not good news im afraid :'(
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4256042  0.57439584]
#
#
# Text: @degrafik The one thing I have learnt is that Sinusitis is a pain in the nose!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3626344 0.6373657]
#
#
# Text: I might have to stop following that particular celeb its ruining my liking of him
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.47804776 0.5219523 ]
#
#
# Text: Yea!!! Calgary won last night!!!!  poor Montreal lost to Ottawa though
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3249923  0.67500776]
#
#
# Text: @kristinabitch I can't believe shes going to be gone in less than 24 hours. I'm going to miss her so much.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3006341 0.699366 ]
#
#
# Text: I'm feeling ecstatic!! I met James Matthews and Josh Wilkinson and got James Towel xD, maan my ears are still ringing and my throat hurts
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31190044 0.68809956]
#
#
# Text: @invokedprojects @kennymeyers There was a post about it. Playcode was Victor who had been previously banned
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38262817 0.6173718 ]
#
#
# Text: @mileycyrus god we have a blizzard here
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38993254 0.6100674 ]
#
#
# Text: @Lady_Twitster not really.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34249356 0.65750647]
#
#
# Text: ugh todays going to be so bad
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3342898 0.6657102]
#
#
# Text: Great, it just started to rain
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.380934 0.619066]
#
#
# Text: So tired of crying...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28672284 0.7132772 ]
#
#
# Text: @ABIBAN ohnoes  what's up bansal?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3378729 0.662127 ]
#
#
# Text: my trainer calls ... I have to go to sport
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3177774  0.68222255]
#
#
# Text: @thatswhack74 aww, thank you so much! i want to see it too
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34456098 0.655439  ]
#
#
# Text: MAKE IT STOP  fu headache and cold why the hell do you come at such wrong times.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33578378 0.66421616]
#
#
# Text: bahah, two days before my birthday, i'll be in the shittest mood ever! D: beware of seb on the 28th of April
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32428995 0.6757101 ]
#
#
# Text: @Nathaniel_3 well im someone's bitch. I cant say no cause i feel guilty. Even though i hate it. And my arms are sore from moving fixtures
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34398085 0.65601915]
#
#
# Text: So far not much going on today.  We will have to wait and see what today brings I guess.  Another yucky day out though.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.294975  0.7050251]
#
#
# Text: omg i slept 2 hours, this sucks. now i'm off to school until 5:30  then i have to memorize my french oral and study for exams :'( too much
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.42734036 0.5726596 ]
#
#
# Text: Up early and off to work till 6:30pm.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.27930114 0.7206989 ]
#
#
# Text: Bleh late for work
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35775918 0.6422408 ]
#
#
# Text: is wondering if she smells? Why else would her two best friends in the world leave her
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3706821  0.62931794]
#
#
# Text: Just woke up. I need more sleep. Funeral at 12
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.32061893 0.67938113]
#
#
# Text: Just got a call from the s2bx: my little one is sick and wants to stay home today.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36279696 0.637203  ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-4fb67479a746> in <cell line: 17>()
#      23
#      24     # Forward pass through the model
# ---> 25     outputs = model(**inputs)
#      26
#      27     # Get probabilities for each class (e.g., positive, negative)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1562         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1563
# -> 1564         outputs = self.bert(
#    1565             input_ids,
#    1566             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1011             past_key_values_length=past_key_values_length,
#    1012         )
# -> 1013         encoder_outputs = self.encoder(
#    1014             embedding_output,
#    1015             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     605                 )
#     606             else:
# --> 607                 layer_outputs = layer_module(
#     608                     hidden_states,
#     609                     attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     537             present_key_value = present_key_value + cross_attn_present_key_value
#     538
# --> 539         layer_output = apply_chunking_to_forward(
#     540             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     541         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     239         return torch.cat(output_chunks, dim=chunk_dim)
#     240
# --> 241     return forward_fn(*input_tensors)
#     242
#     243
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in feed_forward_chunk(self, attention_output)
#     550     def feed_forward_chunk(self, attention_output):
#     551         intermediate_output = self.intermediate(attention_output)
# --> 552         layer_output = self.output(intermediate_output, attention_output)
#     553         return layer_output
#     554
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, input_tensor)
#     462
#     463     def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 464         hidden_states = self.dense(hidden_states)
#     465         hidden_states = self.dropout(hidden_states)
#     466         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax

# %%
import torch
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from torch.nn.functional import softmax
import emoji
import pandas as pd

# Load pre-trained RoBERTa model and tokenizer
# model_name = 'ardiffnlp/twitter-roberta-base-sentiment'
# tokenizer = RobertaTokenizer.from_pretrained(model_name)
# model = RobertaForSequenceClassification.from_pretrained(model_name)

roberta = "cardiffnlp/twitter-roberta-base-sentiment"

model = AutoModelForSequenceClassification.from_pretrained(roberta)
tokenizer = AutoTokenizer.from_pretrained(roberta)

# Example CSV file with a 'tweet' column
csv_file_path = '/content/tweet_data.csv'
df = pd.read_csv(csv_file_path)

# Process each text entry in the CSV file
for index, row in df.iterrows():
    # Example text with emojis
    text = row['tweet']

    # Tokenize and encode the text
    inputs = tokenizer(text, return_tensors='pt', truncation=True)

    # Forward pass through the model
    outputs = model(**inputs)

    # Get probabilities for each class (e.g., positive, negative)
    probs = softmax(outputs.logits, dim=1).detach().numpy()[0]

    # Interpret results
    sentiment_labels = ['Negative', 'Neutral', 'Positive']
    predicted_sentiment = sentiment_labels[probs.argmax()]

    # Map sentiment labels to emojis
    emoji_mapping = {
        'Negative': '😠',
        'Neutral': '😐',
        'Positive': '😊'
    }

    # Get the corresponding emoji for the predicted sentiment
    predicted_emoji = emoji_mapping.get(predicted_sentiment, '')

    print(f"Text: {text}")
    print(f"Predicted Sentiment: {predicted_sentiment} {predicted_emoji}")
    print(f"Sentiment Probabilities: {probs}")
    print("\n")
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Streaming output truncated to the last 5000 lines.
# Text: ooooh.... LOL  that leslie.... and ok I won't do it again so leslie won't  get mad again
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.20825444 0.4729253  0.31882024]
#
#
# Text: Meh... Almost Lover is the exception... this track gets me depressed every time.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.95390856 0.04078398 0.00530738]
#
#
# Text: some1 hacked my account on aim  now i have to make a new one
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7788862  0.20941688 0.01169692]
#
#
# Text: @alielayus I want to go to promote GEAR AND GROOVE but unfornately no ride there  I may b going to the one in Anaheim in May though
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.08944464 0.67448825 0.2360671 ]
#
#
# Text: thought sleeping in was an option tomorrow but realizing that it now is not. evaluations in the morning and work in the afternoon!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.39893368 0.47446367 0.12660262]
#
#
# Text: @julieebaby awe i love you too!!!! 1 am here  i miss you
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00205302 0.01345128 0.98449564]
#
#
# Text: @HumpNinja I cry my asian eyes to sleep at night
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.586192   0.3766779  0.03713006]
#
#
# Text: ok I'm sick and spent an hour sitting in the shower cause I was too sick to stand and held back the puke like a champ. BED now
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9086831  0.07524635 0.01607059]
#
#
# Text: @cocomix04 ill tell ya the story later  not a good day and ill be workin for like three more hours...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8314027  0.15129878 0.01729857]
#
#
# Text: @MissXu sorry! bed time came here (GMT+1)   http://is.gd/fNge
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5249293  0.43259355 0.0424772 ]
#
#
# Text: @fleurylis I don't either. Its depressing. I don't think I even want to know about the kids in suitcases.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9632169  0.03300213 0.00378099]
#
#
# Text: Bed. Class 8-12. Work 12-3. Gym 3-5 or 6. Then class 6-10. Another day that's gonna fly by. I miss my girlfriend
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.46137026 0.3501065  0.1885233 ]
#
#
# Text: really don't feel like getting up today... but got to study to for tomorrows practical exam...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.64120185 0.31182882 0.04696929]
#
#
# Text: He's the reason for the teardrops on my guitar the only one who has enough of me to break my heart
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.25237378 0.5158529  0.2317733 ]
#
#
# Text: Sad, sad, sad. I don't know why but I hate this feeling  I wanna sleep and I still can't!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9695058  0.02568763 0.00480657]
#
#
# Text: @JonathanRKnight Awww I soo wish I was there to see you finally comfortable! Im sad that I missed it
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.4365217  0.34409785 0.21938041]
#
#
# Text: Falling asleep. Just heard about that Tracy girl's body being found. How sad  My heart breaks for that family.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9374056  0.05635616 0.00623825]
#
#
# Text: @Viennah Yay! I'm happy for you with your job! But that also means less time for me and you...
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00463013 0.0297032  0.96566665]
#
#
# Text: Just checked my user timeline on my blackberry, it looks like the twanking is still happening  Are ppl still having probs w/ BGs and UIDs?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4500374  0.5248507  0.02511192]
#
#
# Text: Oh man...was ironing @jeancjumbe's fave top to wear to a meeting. Burnt it
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5338625  0.3993331  0.06680449]
#
#
# Text: is strangely sad about LiLo and SamRo breaking up.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8054753  0.17939624 0.0151285 ]
#
#
# Text: @tea oh! i'm so sorry  i didn't think about that before retweeting.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.68577605 0.2783363  0.03588768]
#
#
# Text: Broadband plan 'a massive broken promise' http://tinyurl.com/dcuc33 via www.diigo.com/~tautao Still waiting for broadband we are
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5834981 0.3752933 0.0412086]
#
#
# Text: @localtweeps Wow, tons of replies from you, may have to unfollow so I can see my friends' tweets, you're scrolling the feed a lot.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.60099316 0.33249846 0.0665083 ]
#
#
# Text: our duck and chicken are taking wayyy too long to hatch
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.86340827 0.12408441 0.0125073 ]
#
#
# Text: Put vacation photos online a few yrs ago. PC crashed, and now I forget the name of the site.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.86523694 0.12278461 0.01197842]
#
#
# Text: I need a hug
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30619377 0.5634181  0.13038808]
#
#
# Text: @andywana Not sure what they are, only that they are PoS! As much as I want to, I dont think can trade away company assets sorry andy!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.50445604 0.43429932 0.06124471]
#
#
# Text: @oanhLove I hate when that happens...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.93029594 0.06165032 0.00805367]
#
#
# Text: I have a sad feeling that Dallas is not going to show up  I gotta say though, you'd think more shows would use music from the game. mmm
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.76189834 0.21313855 0.02496306]
#
#
# Text: Ugh....92 degrees tomorrow
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.61273766 0.31250402 0.0747584 ]
#
#
# Text: Where did u move to?  I thought u were already in sd. ?? Hmmm. Random u found me. Glad to hear yer doing well.
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00440557 0.09763956 0.8979548 ]
#
#
# Text: @BatManYNG I miss my ps3, it's out of commission  Wutcha playing? Have you copped 'Blood On The Sand'?
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.49498087 0.46208912 0.04293007]
#
#
# Text: just leaving the parking lot of work!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.10163256 0.6077147  0.2906528 ]
#
#
# Text: The Life is cool. But not for Me.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36605537 0.48206723 0.15187739]
#
#
# Text: Sadly though, I've never gotten to experience the post coitus cigarette before, and now I never will.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8892347  0.10087296 0.0098924 ]
#
#
# Text: I had such a nice day. Too bad the rain comes in tomorrow at 5am
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.12878561 0.26048723 0.61072713]
#
#
# Text: @Starrbby too bad I won't be around I lost my job and can't even pay my phone bill lmao aw shucks
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.95879877 0.03636396 0.00483735]
#
#
# Text: Damm back to school tomorrow
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.09126681 0.78359604 0.12513714]
#
#
# Text: Mo jobs, no money.  how in the hell is min wage here 4 f'n clams an hour?
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8929794  0.09606232 0.01095831]
#
#
# Text: @katortiz  Not forever... See you soon!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00826263 0.23540223 0.7563352 ]
#
#
# Text: @Lt_Algonquin agreed, I saw the failwhale allllll day today.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.12365627 0.6021332  0.27421048]
#
#
# Text: @jdarter Oh! Haha... dude I dont really look at em unless someone says HEY I ADDED YOU. Sorry  I'm so terrible at that. I need a pop up!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.78194517 0.1744577  0.04359707]
#
#
# Text: @ninjen I'm sure you're right...    I need to start working out with you and the Nikster... Or Jared at least!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.01920495 0.49242836 0.48836666]
#
#
# Text: i really hate how people diss my bands!  Trace is clearly NOT ugly!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9439652  0.04876158 0.00727325]
#
#
# Text: Gym attire today was: Puma singlet, Adidas shorts.......and black business socks and leather shoes  Lucky did not run into any cute girls.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.42077175 0.44053146 0.1386968 ]
#
#
# Text: Why won't you show my location?!   http://twitpic.com/2y2es
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.63264376 0.34065658 0.02669974]
#
#
# Text: No picnic  my phone smells like citrus.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6040515  0.31186575 0.08408277]
#
#
# Text: @ashleyac My donkey is sensitive about such comments. Nevertheless, he'd (and me'd) be glad to see your mug asap. Charger is still awol.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.0792008  0.47582796 0.44497126]
#
#
# Text: No new csi tonight.  FML
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.62264866 0.32079023 0.05656109]
#
#
# Text: i think my arms are sore from tennis
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7729858  0.20598231 0.02103193]
#
#
# Text: wonders why someone that u like so much can make you so unhappy in a split seccond . depressed .
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8706381  0.11738449 0.01197749]
#
#
# Text: sleep soon... i just hate saying bye and see you tomorrow for the night.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.85027725 0.12735918 0.02236352]
#
#
# Text: @statravelAU just got ur newsletter, those fares really are unbelievable, shame I already booked and paid for mine
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.71475536 0.22792235 0.05732236]
#
#
# Text: missin' the boo
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.29270774 0.60004365 0.10724863]
#
#
# Text: @markhardy1974 Me too  #itm
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.07016832 0.79540664 0.13442509]
#
#
# Text: Damn... I don't have any chalk! MY CHALKBOARD IS USELESS
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.78013563 0.17784148 0.04202291]
#
#
# Text: had a blast at the Getty Villa, but hates that she's had a sore throat all day. It's just getting worse too
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7650024 0.1817733 0.0532243]
#
#
# Text: @msdrama hey missed ya at the meeting  sup mama
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2740967  0.6322034  0.09369994]
#
#
# Text: My tummy hurts.  I wonder if the hypnosis has anything to do with it? If so, it's working, I get it, STOP SMOKING!!!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8004172  0.17559955 0.02398326]
#
#
# Text: why is it always the fat ones?!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8349092  0.14912978 0.01596105]
#
#
# Text: @januarycrimson Sorry, babe!!  My fam annoys me too. Thankfully, they're asleep right now. Muahaha. *evil laugh*
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.50892836 0.3465586  0.14451303]
#
#
# Text: @Hollywoodheat I should have paid more attention when we covered photoshop in my webpage design class in undergrad
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5362221  0.40233764 0.06144021]
#
#
# Text: wednesday my b-day! don't know what 2 do!!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3789833  0.38911808 0.23189865]
#
#
# Text: Poor cameron (the hills)
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.71475583 0.2612197  0.02402446]
#
#
# Text: pray for me please, the ex is threatening to start sh** at my/our babies 1st Birthday party. what a jerk. and I still have a headache
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.963625   0.03237707 0.00399789]
#
#
# Text: @makeherfamous hmm  , do u really enjoy being with him ? if the problems are too constants u should think things more , find someone ulike
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28740552 0.5733222  0.13927229]
#
#
# Text: Strider is a sick little puppy  http://apps.facebook.com/dogbook/profile/view/5248435
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.86408204 0.12047013 0.01544775]
#
#
# Text: so rylee,grace...wana go steve's party or not?? SADLY SINCE ITS EASTER I WNT B ABLE 2 DO MUCH  BUT OHH WELL.....
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34312135 0.51269794 0.1441807 ]
#
#
# Text: hey, I actually won one of my bracket pools! Too bad it wasn't the one for money
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.04428308 0.24477302 0.71094394]
#
#
# Text: @stark YOU don't follow me, either  and i work for you!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6585938  0.3105309  0.03087525]
#
#
# Text: A bad nite for the favorite teams: Astros and Spartans lose.  The nite out with T.W. was good.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33568454 0.4183914  0.24592403]
#
#
# Text:  Body Of Missing Northern Calif. Girl Found: Police have found the remains of a missing Northern California girl .. http://tr.im/imji
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.11417873 0.8460034  0.03981778]
#
#
# Text: @mangaaa I hope they will increase the capacity fast, yesterday was such a pain. Got the fail whale +15 times in 2 hours....
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5095688  0.3991988  0.09123239]
#
#
# Text: Behind on my classes for work
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.25843638 0.6667806  0.07478301]
#
#
# Text: watching &quot;House&quot;
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.04496547 0.877285   0.0777495 ]
#
#
# Text: @kpreyes Remember my bum leg? Strikes back this time its serious
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.23742288 0.64958185 0.11299519]
#
#
# Text: @paradisej cool, i will. their are all kinds of complaints about this laptop online about overheating, but no recalls
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.26256526 0.49251616 0.24491857]
#
#
# Text: Emily will be glad when Mommy is done training at her new job. She misses her.  http://apps.facebook.com/dogbook/profile/view/6176014
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01246915 0.14324203 0.8442888 ]
#
#
# Text: would rather the first party send bad messages than the 3rd party send mixed ones  Sophmore year all over again?
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.66227597 0.31661615 0.02110787]
#
#
# Text: @Henkuyinepu it's overrated
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6416349  0.3158947  0.04247046]
#
#
# Text: @marykatherine_q i know! I heard it this afternoon and wondered the same thing. Moscow is so behind the times
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5240918  0.41788766 0.05802051]
#
#
# Text: laying in bed with no voice..
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6208871  0.34782365 0.03128928]
#
#
# Text: I'm sooo sad!!! they killed off Kutner on House  whyyyyyyyy
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9736302  0.02368946 0.0026803 ]
#
#
# Text: @jacobsummers Sorry  tell them mea culpa from me and that I really am sorry.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41690406 0.50437236 0.0787236 ]
#
#
# Text: @Alliana07 it didn't make any sense to me, the suicide thing. I refuse to believe that that is actually what happened.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.93019074 0.06487217 0.00493707]
#
#
# Text: @salancaster  hope your ok.
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.0122934  0.33112556 0.65658104]
#
#
# Text: @mercedesashley Damn! The grind is inspirational and saddening at the same time.  Don't want you to stop cuz I like what u do! Much love
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01933873 0.07386421 0.90679705]
#
#
# Text: @HibaNick yeah aw but i know i wudnt stand a chance
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.77640355 0.2106351  0.01296134]
#
#
# Text: ugh. cant sleep. its 1:30am.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.87571555 0.10358573 0.02069868]
#
#
# Text: Hanging in Crooners. Wanna sing. Can't. Sucks.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.92685604 0.06191155 0.01123242]
#
#
# Text: @eRRe_sC aaw i miss ya all too.. im leaving to BH tomorrow &quot;morning&quot; i think.. aww i wanna go to the beach w u girls!!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01748063 0.19847499 0.7840443 ]
#
#
# Text: Is pissed off that there's no ASBA's for a radio station.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.85452163 0.13160579 0.01387261]
#
#
# Text: wednesday my b-day n don't know what 2 do!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5649708  0.34049857 0.09453063]
#
#
# Text: I know my life has been flipped upside down when I just thought in my head that some Ramen sounds good.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.34428036 0.41243216 0.2432875 ]
#
#
# Text: I am in pain. My back and sides hurt. Not to mention crying is made of fail.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9576193  0.03742461 0.00495618]
#
#
# Text: Late night snack, glass of OJ b/c I'm &quot;down with the sickness&quot;, then back to sleep...ugh I hate getting sick...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9623351  0.03107288 0.00659202]
#
#
# Text: @allyheman but.. but.. but.. I'm not a big fan on camilla belle
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8372356  0.15275952 0.01000489]
#
#
# Text: @grum WAH I can't see clip, must be el-stupido work filters. Can't wait 'till I get a 'puter. Something else 2 blame ex 4. He broke mine
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.61619544 0.2885937  0.09521085]
#
#
# Text: This week just seems to get longer and longer in terms of how much I need to do.. and how much I'm actually going to get done
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.48646024 0.43329763 0.0802421 ]
#
#
# Text: I'm so cold
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.78692806 0.18435048 0.02872145]
#
#
# Text: @thecoolestout Ehhh don't. Weather's gonna take a turn for the ugly tomorrow
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6554584  0.28874478 0.05579688]
#
#
# Text: @chelserlynn haha its so cooooold in the d! and no  but you should still go to the show. they do some incredible stuff
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00247703 0.01895015 0.9785728 ]
#
#
# Text: Hoping the tummy rumbles go away soon
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.16518502 0.6334454  0.20136954]
#
#
# Text: @Knights_ No, no notice. They told me I'd be working tomorrow, and then I called the agency to follow up and they said it was over.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35492694 0.5930861  0.05198684]
#
#
# Text: almost bedtime
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.11583101 0.66837597 0.21579297]
#
#
# Text: I'm missing you babe..  but as long as your alive I'm happy.. Yawwwnn.. I'm tired my love imma try to sleep hopefully you had a headstart
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01953773 0.16264437 0.81781787]
#
#
# Text: Agh...snow!!!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6643185  0.2552244  0.08045709]
#
#
# Text: i miss kenny powers
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.44349468 0.47214136 0.08436395]
#
#
# Text: @BridgetsBeaches Thank you for letting people know, but now I'm sad that the direct message I got wasn't actually from Bridget
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.56091744 0.37439314 0.06468945]
#
#
# Text: ...and, India missed out its 100th Test victory n 10th consecutive win without a loss.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.45521882 0.4766091  0.06817205]
#
#
# Text: @JonathanRKnight I guess that's a no then.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.54381096 0.42901322 0.02717587]
#
#
# Text: sadly is going to bed.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5271182  0.41820136 0.0546804 ]
#
#
# Text: @ozesteph1992 Shame to hear this Stephan
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7761521  0.20595111 0.01789684]
#
#
# Text: @mrsaintnick hey! i'm leavin in the morning...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.00961659 0.7254258  0.26495767]
#
#
# Text: Was intending to finish editing my 536-page novel manuscript tonight, but that will probably not happen. And only 12 pages are left
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6147358  0.3346147  0.05064956]
#
#
# Text: laid around too much today... now my head hurts
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9361944  0.05633141 0.00747411]
#
#
# Text: @twista202 I still haven't read the 9th&amp;10th Princess diaries  Saving Francesca made me cry at the end. Hmm those are easy books.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.57595915 0.33939135 0.08464949]
#
#
# Text: my nokia 1110 died..
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.87296426 0.11770783 0.00932788]
#
#
# Text: My mom might have breast cancer won't find out anything for. Like a week I'm so worried!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9529294  0.04301131 0.00405937]
#
#
# Text: Going to sleep. Hoping tomorrow is a better day.
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.0036056  0.08296157 0.91343284]
#
#
# Text: @rumblepurr lol.. wish they understood daylight savings has ended though and breakfast is an hour later  They keep waking the kids up too
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.49574193 0.42504328 0.07921469]
#
#
# Text: @onemoreproject that is lame
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.876143   0.10582282 0.01803425]
#
#
# Text: I don't understand... I really don't
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9089535  0.08146213 0.00958443]
#
#
# Text: HEROES just isn't doing it for me this season...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.94232583 0.05193511 0.00573906]
#
#
# Text: Living not downtown sure isn't much fun.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7228234  0.22066739 0.05650923]
#
#
# Text: @jonathanchard Not calorie wise   I wish junk food was calorie free! I ate a thing of sour skittles and a big ass cherry coke!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8145792  0.14942443 0.03599643]
#
#
# Text: Man Work is Hard
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.56632876 0.3819805  0.05169079]
#
#
# Text: getting sick  time for some hot tea, studying, and then sleeeep
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37879837 0.47729987 0.14390175]
#
#
# Text: Getting eyebrows waxed. More pain
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.54546505 0.39362544 0.06090948]
#
#
# Text: No phantasy star yesterday  going to work...
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.1752148  0.72979575 0.0949895 ]
#
#
# Text: Oh - Just got all my MacHeist 3.0 apps - sweet. Didn't get the Espresso serial no though although they said they sent it - oh well
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.05479311 0.26628232 0.67892456]
#
#
# Text: Picked Mich St to win it all from the get go.  Was feeling pretty good about that pick all the way up until......tonight.  A's lost too
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.15880789 0.37065095 0.47054115]
#
#
# Text: is alone downstairs...working
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.24252798 0.69383734 0.0636347 ]
#
#
# Text: I feel bad for doing it
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8767684  0.11009138 0.01314025]
#
#
# Text: @RyanSeacrest is it just me, or she hates anoop. i mean seriously, she's kinda mean to him.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8660972  0.12348383 0.0104189 ]
#
#
# Text: @pinkserendipity yes sprint has 4g only in baltimore and chicago so far
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.00665904 0.5415942  0.45174676]
#
#
# Text: I'm stuck awake in the middle of the night for the second day in a row. And I felt terrible yesterday.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9646484  0.03164423 0.00370732]
#
#
# Text: Thanks for bursting my bubble
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.03957716 0.20187913 0.7585437 ]
#
#
# Text: Going to school soon... can't find anything to wear!! gosh it's so hard
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.875599   0.10543336 0.01896759]
#
#
# Text: @marieclr I was serious  LOL
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.05661105 0.55385983 0.38952908]
#
#
# Text: @naughtyhaughty I had on my page for sooooo long!!! Until it got deleted  Sad day in history
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7932053  0.17406318 0.03273153]
#
#
# Text: Crazy wind today = no birding  http://ff.im/1XTTi
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3280558  0.56435055 0.10759369]
#
#
# Text: currently at work..
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.10510278 0.8160938  0.07880337]
#
#
# Text: Grrr.. my ipods acting weird too! Jai ho and thinking of you aren't playing the full songs.. ughh.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.918055   0.07321543 0.00872969]
#
#
# Text: @penndbad send me the DVD cos I have missed out on heaps  NOT happy about that!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.94452137 0.04866741 0.00681128]
#
#
# Text: i don't see the big deal with this website
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8550018  0.13367586 0.01132231]
#
#
# Text: @machineplay I'm so sorry you're having to go through this. Again.  #therapyfail
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.92729014 0.06397652 0.00873336]
#
#
# Text: @ColinDeMar Far too out of the way for rail.  any other tips?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3894395  0.5679918  0.04256875]
#
#
# Text: I'm not still up I swear. Why do I keep losing. gaining. losing. gaining. tweeps?  So heart wrenching.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.96148187 0.03490075 0.00361745]
#
#
# Text: Today I realized I am too good at hiding things, even I can't find it
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.49178794 0.38889107 0.11932104]
#
#
# Text: Staying at a friends house...house sitting, neighbors are SO loud-having a party
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.19666222 0.52846926 0.27486846]
#
#
# Text: @dannyvegasbaby danny im upset that i wasnt here to watch the live chat  i was in a car. for 3 hours on a trip im soooo upset!!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9570808  0.03870686 0.00421248]
#
#
# Text: Check out my mug  http://www.erika-obscura.blogspot.com
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.02597358 0.87953764 0.09448866]
#
#
# Text: Borders closed at 10
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.08579253 0.8677279  0.0464797 ]
#
#
# Text: Downloading NIN's new album &quot;the slip&quot; - when the hell did this come out? I'm so behind the times these days
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8189943  0.1552885  0.02571718]
#
#
# Text: Just woke up an already have written some e-mail... I've to go early at University today as I have to teach at 8:30 AM!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.11917322 0.67724866 0.20357807]
#
#
# Text: is watching the hill . . .and its making me sad
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9196249  0.07152732 0.00884772]
#
#
# Text: So many channels.... yet so so boring... lazy day again  may have to find a hobby
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.89713067 0.08538499 0.01748437]
#
#
# Text: @supersport I miss my buddy  ill be in NY on the 25th
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.42304462 0.46572253 0.11123289]
#
#
# Text: @robluketic  love the french. I tell people here in the south i'm qtr. french and they snarl at me.  french are beautiful people
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00345323 0.0138351  0.98271173]
#
#
# Text: Opps.. As I said.. I still got one day remain and now problem come
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6108996  0.35217297 0.0369274 ]
#
#
# Text: I activated my Selfcontrol block early, meaning I can't check out the new QC.  Regularizing my internal clock is might be difficult. #fb
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7809733  0.20243788 0.01658884]
#
#
# Text: @HillyDoP  oH NO
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.607419   0.36213776 0.0304432 ]
#
#
# Text: spencer is not a good guy.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.91213834 0.07915733 0.00870426]
#
#
# Text: @goodlaura What about Reese dying on #TTSC? And season finale next week.  #24 boring, Madame President is a crazy woman.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8805356  0.10937352 0.01009093]
#
#
# Text: @JonathanRKnight I hate the limited letters,too.Hope you and the guys are fine?I pray for my dog,sheï¿½s not well
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7452927  0.22067015 0.03403711]
#
#
# Text: didn't get shit done today ~ i'm so screwed
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9568207  0.03644573 0.00673351]
#
#
# Text: wanttss to go out
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.02532323 0.5486324  0.42604434]
#
#
# Text: Is not going to sleep tonite.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6386352  0.3312157  0.03014913]
#
#
# Text: too worried and tired to post tonight
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8312743  0.15310115 0.01562458]
#
#
# Text: couldn't get shit done today ~ i'm so screwed
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.96118057 0.03344345 0.00537603]
#
#
# Text: Job Interview in Cardiff today, wish me luck! Got about 3 hours sleep
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00311123 0.10048016 0.8964086 ]
#
#
# Text: @stustone Your show is whack. Way worse than whack, it's wiggety-whack.    :*(:*(:*(
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.98155886 0.01530648 0.00313477]
#
#
# Text: @DjAlizay I really don't think people choose to be that way. But I think he chose not to accept my family's help   He might be dead by now
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.87686986 0.11654349 0.00658657]
#
#
# Text: @eloquentembrace You're going to kill me, but I've not seen DS9. I've been waiting till I can do it in one solid week sitting.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5772442  0.3557776  0.06697826]
#
#
# Text: @cheechbud i think ur right!! hahaha!! 4.5 hrs now!!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00937523 0.17366858 0.8169562 ]
#
#
# Text: i hate to see the spartans so sad
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9551149  0.03935108 0.00553395]
#
#
# Text: My mind and body are severely protesting this &quot;getting up&quot;  thing. Had nightmares to boot
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9418233  0.05273335 0.00544344]
#
#
# Text: @MySteezRadio I'm goin' to follow u, since u didn't  LOL  GO ANGELS!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.02990036 0.32176438 0.64833516]
#
#
# Text: @mandayyy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.12678155 0.632434   0.24078442]
#
#
# Text: @twista202 I think I want to read some books but the library doesn't have them
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5594035  0.39108625 0.0495102 ]
#
#
# Text: My nap was interrupted so many times today  Going out for Japanese with the 'rents again...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.81278473 0.16865659 0.01855872]
#
#
# Text: Kind of longs for the bus that shows up at the end of Ghost World right now. Ugh.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.598497   0.3224191  0.07908402]
#
#
# Text: @GuruMN but this is canada  canada is weird. we're supposed to get snow through wednesday. ugh.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.84536564 0.13620903 0.01842534]
#
#
# Text: Awwh babs... you look so sad underneith that shop entrance of &quot;Yesterday's Musik&quot;  O-: I like the look of the new transformer movie
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2184233  0.4411219  0.34045482]
#
#
# Text: sad that the 'feet' of my macbook just fell off
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8913478  0.09848807 0.01016412]
#
#
# Text: I'm gonna get up late tomorrow and it's 132am here. I gonna get tipsy by my lonesome. That's...that's just sad
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6841047  0.23601262 0.07988267]
#
#
# Text: I'm sweating my forthcoming trip to E3.  If I can't find someone to crash with while I'm out there, I may be screwed.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.79981035 0.16779856 0.03239097]
#
#
# Text: Has now gotten somebody to read his tweets, but cant get them to make an account.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.46776178 0.49062374 0.04161446]
#
#
# Text: @infinitydefines  omgawd i couldnt handle my cat being in heat all the time D: D:
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9384002  0.05516261 0.00643724]
#
#
# Text: @DonnieWahlberg I hope i can make it to the auburn show. but its not looking good for me
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7203629  0.24106675 0.03857038]
#
#
# Text: @David_Henrie *thats people mag haha i couldnt fit it all in.. i dont think those pictures ever made it in the magazine tho!  haha
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5886834  0.34614006 0.06517652]
#
#
# Text: @breadandbadger Congrats!!  i totally forgot to submit photos
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00905648 0.05891677 0.93202674]
#
#
# Text: @PaulaAbdul awww, Good luck Paula!! Please don't work too hard  but I hope you have fun  Your new album is gonna be amazing!  xxx
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00139627 0.00862304 0.98998064]
#
#
# Text: @imaginarypeach now your leaving me  .... -gets sad-
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.84322375 0.14339067 0.0133856 ]
#
#
# Text: I miss you twitter. My phone broke, now I'm using a stupid Nokia phone. Ughhh, I miss my advance phone.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.93984646 0.05078032 0.00937321]
#
#
# Text: SHOOTING OUTSIDE MY HOUSE :O NOT KIDDING! So SCARED
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.80873597 0.16678418 0.02447989]
#
#
# Text: Tuesdayï¿½ll start with reflection ï¿½n then a lecture in Stress reducing techniques. That sure might become very useful for us accompaniers
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00853266 0.15940759 0.8320598 ]
#
#
# Text: What tragedy and disaster in the news this week
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9202612  0.07198158 0.00775717]
#
#
# Text: yes yes still trying to find a picture that will upload correclty..
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.08111239 0.66101557 0.25787202]
#
#
# Text: Why oh why was the Red Sox game rained out? I was so looking forward to opening day
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38828677 0.39880762 0.21290559]
#
#
# Text: I still can't find my keys.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.90408534 0.08785319 0.00806152]
#
#
# Text: @charlietm I know right. I dunno what is going on with twitter.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.68192726 0.2922766  0.02579616]
#
#
# Text: might be getting a sore throat again
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.74518883 0.23205398 0.02275714]
#
#
# Text: @labelsnotlove   my home town. My mammy called all depressd.  Pls explain y a parent let their 8yr old child walk alone? Hello? Its 2009!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.89684045 0.09376778 0.00939177]
#
#
# Text: @ircmaxell - I think I need to find better anti-depressants.  I think this Paxil/Wellbutrin combo is losing its efficacy.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8372312  0.14866202 0.01410677]
#
#
# Text: @MyConnecticut Restaurant called WoodNTap has competitive eating tourney round tourney time. We place 2nd
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.00836882 0.8239535  0.16767766]
#
#
# Text: is in the bathroom... wake up lakin.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3559814  0.5987323  0.04528636]
#
#
# Text: @CaitlinOConnor i want tacos and margarhitas  telll gay i say hello&lt;3
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00829873 0.2340625  0.7576388 ]
#
#
# Text: im lonely  keep me company! 22 female, california
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.24307911 0.6359428  0.12097804]
#
#
# Text: bad day at the betfair office
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8457269  0.14088869 0.01338434]
#
#
# Text: I miss him.  Can't wait to celebrate the Tar Heel win this weekend though!!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00374745 0.02534704 0.9709055 ]
#
#
# Text: I'm really cold. I don't want to go to sleep yet but there's nothing to do
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8615094  0.12138663 0.01710406]
#
#
# Text: @kristencampisi is this it 4 u? Its ' officially over ' 4 me this go round!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.27182668 0.5686432  0.15953013]
#
#
# Text: monkeys??? i just found out you my twin and you wont even write back.  i'm heartbroken
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.95761395 0.03898941 0.00339662]
#
#
# Text: @miss_om Aww  I know I felt like that yesterday at work
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.59398794 0.36854157 0.03747057]
#
#
# Text: @SarahReedSC treaty isn't defined
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.33990777 0.6286042  0.03148805]
#
#
# Text: missed Brent at praise band.   No fun to not have the your lead guitarist.  &lt;pout&gt;
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.67809904 0.2666978  0.05520308]
#
#
# Text: @jpfurry poor john  this is what happens when you play with fruit and a microwave! Seriously though HAVE you seen a doctor?? Xxx
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.70322996 0.26382872 0.03294126]
#
#
# Text: Missing My BFF  watching home and away it reminds me of her and me  we &lt;3 It. shout out to u courts
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00204924 0.03885191 0.9590988 ]
#
#
# Text: @mandayyy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.09563138 0.7246332  0.17973538]
#
#
# Text: New video card is DOA.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.05752466 0.8108569  0.13161846]
#
#
# Text: feeling lost, naked and confused (JK, sort of).....no iphone for me.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8372936  0.14714938 0.01555696]
#
#
# Text: Damn i am so late at filling this appraisal form, people have almost sent it .. i was so occupied in work
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.84551305 0.13548023 0.01900676]
#
#
# Text: missed Brent at praise band.  No fun to not have your lead guitarist. &lt;pout&gt;
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.70570785 0.24246854 0.05182363]
#
#
# Text: i think to much on the past. i cant change it. i deserved so much more then wat i got. ..but why am i still thinking about him  gah
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7184532  0.2410742  0.04047257]
#
#
# Text: has lost his ring. It's no-where to be seen
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.71067446 0.26583856 0.02348697]
#
#
# Text: @burgaw Ooooooh! *sealclap* See, I download shitloads of zip folders off 4chan. I have no internet moneys.  FUCK YEAH ALICIA &amp; MIKEY.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9260016  0.06255108 0.01144722]
#
#
# Text: Is still nursing my Nile but glad he is feeling better. I hate when my baby is sick
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.4951037  0.3378383  0.16705798]
#
#
# Text: Is fucked to go back to IC
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.87066215 0.11647131 0.01286654]
#
#
# Text: @Brandizzzle08 yoyoyo. my internet has been rude tonight. it JUST reconnected and I'm about to go to bed.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.84121555 0.13753426 0.02125023]
#
#
# Text: @jemcam well i have uni stuff and netball  but after netbal if i've done uni stuff we can
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.03357941 0.8644013  0.10201941]
#
#
# Text: @kissability Me too I is poor
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6394301  0.32389086 0.03667906]
#
#
# Text: help me forget 8th april &amp; 13th july!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.12209644 0.46355146 0.4143521 ]
#
#
# Text: dierks bentley is comin' to columbus, OH!! i wanna go so bad
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.22535765 0.3379125  0.43672988]
#
#
# Text: i have to take my sidekick back.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4118465  0.56056786 0.02758565]
#
#
# Text: @chriscantore congrats! I'm totally jealous! only wish my XM was working
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.21994169 0.31569213 0.4643662 ]
#
#
# Text: gr8t my face is very itchy
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.850506   0.13310577 0.01638822]
#
#
# Text: poor socks  luvvvvv the golden retriever!! I want one sighhhh
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00543574 0.03567545 0.9588888 ]
#
#
# Text: I just saw that they found that Tracy girl in a piece of luggage... How fucking terrible
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.97129595 0.0256909  0.00301317]
#
#
# Text: Aaaaand the nausea is back.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.84983563 0.12969658 0.02046769]
#
#
# Text: @DonnieWahlberg ooh Iï¿½m excited and not even going 2 be there  long love YOUTUBE!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.0021526  0.00772675 0.99012065]
#
#
# Text: spent 1 hour to reach to Axis bank only to find out today is holiday for Mahavir Jayanti  contd..
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.38313898 0.56818914 0.04867182]
#
#
# Text: @mathewsmichael  i agree... the jobros dont update theres very often
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.31946367 0.5913628  0.08917353]
#
#
# Text: @fishmouse it is hilarious and I linked the clip from LJ some time ago but when I went back just now it was a dead link
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.09240971 0.42259422 0.48499617]
#
#
# Text: @DiannePulham OOOOOOOO who with? (im not neither but thats because i need to study  )
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.36345786 0.5304261  0.10611605]
#
#
# Text: Haven't tweeted nearly all day  Posted my website tonight, hopefully that goes well  Night time!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00659065 0.12839532 0.8650141 ]
#
#
# Text: @bostongarden I miss bentley
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.28822947 0.6100686  0.10170192]
#
#
# Text: seriously needs to finish these job applications
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37023613 0.559192   0.07057186]
#
#
# Text: My son Vincas is sick, so I stay at home  Just three tense days at work, and I am back on holiday with kids
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5169981  0.41849524 0.06450662]
#
#
# Text: Whinging. My client&amp;boss don't understand English well. Rewrote some text unreadable. It's written by v. good writer&amp;reviewed correctly.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7659197  0.20425378 0.02982651]
#
#
# Text: @huntermoore I don't want him to ever punch me.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.67770946 0.29166254 0.03062796]
#
#
# Text: sooo sick of the snow  ughh
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.96083945 0.03130386 0.00785668]
#
#
# Text: @ITS_NEMESIS -------
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.08658984 0.8096922  0.10371797]
#
#
# Text: @LoveMeagan it doesn't work your fan is upset
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8274177  0.15603864 0.01654368]
#
#
# Text: I would like to apologize for the repeated Video Games Live related tweets. I am going to have a stern discussion with Koodo soon. Stern.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3569064  0.5729683  0.07012524]
#
#
# Text: @zaydia but i cant figure out how to get there / back / pay for a hotel etc
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7854729  0.20200475 0.01252238]
#
#
# Text: FML: So much for seniority, bc of technological ineptness, I now have to &quot;register&quot; for classes AGAIN
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.87234926 0.11256953 0.0150812 ]
#
#
# Text: feels like she slept the day away.    Not looking forward to any more bouts with my gallbladder.  At least I have pills now for the pain.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7349108  0.22670813 0.03838116]
#
#
# Text: @ThaStevieG but what I really want is my old bass back
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.06961118 0.5619861  0.36840272]
#
#
# Text: Mad tired today... Callin it in early tonight  nighty night twittas
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5462233  0.38781625 0.06596049]
#
#
# Text: @LevenRambin: Take it easy, and be good to you.
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01074096 0.2231445  0.76611453]
#
#
# Text: I'm afraid I had bad code.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8171986  0.16888672 0.0139147 ]
#
#
# Text: Think I'm going to bed. Goodniight. I hate this
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9227388  0.06474077 0.01252041]
#
#
# Text: @riancurtis  i'm here, friend, and i love you.
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00223048 0.02866195 0.9691076 ]
#
#
# Text: @kariajay  All this time you didn't notice I was gone...just needed DB2 is it??
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.30635467 0.63112146 0.06252392]
#
#
# Text: @aaronrva is in the bathroom and i have to pee!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7401953  0.23529202 0.02451274]
#
#
# Text: @ashleyskyy but I wanted a margarita too!
# Predicted Sentiment: Positive 😊
# ...
# Sentiment Probabilities: [0.18385355 0.4392265  0.37691987]
#
#
# Text: @mattycus  *cry*
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3787587  0.5319002  0.08934106]
#
#
# Text: @RumLover An empty rum barrel is a sad rum barrel. *shakes head* the horror, the horror.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.82663643 0.15219682 0.02116683]
#
#
# Text: It was a sleepless night
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4073114 0.528523  0.0641655]
#
#
# Text: @BillyBush she admitted to being a fake
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7517513  0.23363075 0.01461791]
#
#
# Text: @BATMANNN  i love chutney......
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00314794 0.02620453 0.9706476 ]
#
#
# Text: got highly bored today scanning 24 pages for daddy. Had to do it!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7003462  0.2466608  0.05299301]
#
#
# Text: @misterphipps you cooked risotto without me!!???
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.46901748 0.48115408 0.04982838]
#
#
# Text: Keeeerrrrriiiiii!!!!  I really have nothing better to do then post on this thing at 224am.....wonderfullll. Says alot.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.4842579  0.34314173 0.17260031]
#
#
# Text: YAY FOR BASEBALL SEASON! boo to yankees losing their first game
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.15482911 0.364192   0.48097885]
#
#
# Text: LOST sucks  ... because i have to work today
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9388757  0.04934008 0.01178418]
#
#
# Text: omg exams killed me  how could i not know the difference between haif a circle and a hemisphere &lt;/3 &gt;
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.89512056 0.09339903 0.01148035]
#
#
# Text: In bed... I suddenly feel  I wish MA was here w/me... Goodnight TwitterFam
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.23016691 0.53382504 0.23600806]
#
#
# Text: @RachelCmrn I don't like goodnights
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9321712  0.06143667 0.00639204]
#
#
# Text: Greaaat my lappy won't turn on  wtffffff
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.90124786 0.08812147 0.0106307 ]
#
#
# Text: @M4RKM  You stuck in traffic then? My journey was traffic free this morning, if it's any help.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.09427547 0.7043955  0.20132898]
#
#
# Text: Lookin like an all-nighter. I hate it when I do this to myself
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9465237  0.04594812 0.00752817]
#
#
# Text: @vernonhamilton You're a stranger
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37346256 0.5609322  0.0656052 ]
#
#
# Text: Debbugging old VB6 code, the day could have started better . . .
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.3684424  0.40882617 0.2227314 ]
#
#
# Text: @toddlington only a quarter of a percent babe  darn
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.4114874  0.52700526 0.06150732]
#
#
# Text: Coming down with a cold or bad allergies. Either way, I'm miserable!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9248074  0.0627907  0.01240191]
#
#
# Text: Can't believe Cutner is dead on House! Sad day.  in Santa Rosa, CA http://loopt.us/ORPL3A
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9276161  0.06417035 0.00821348]
#
#
# Text: Damnit I was really digging this season of Reaper  http://www.tv.com/story/13720.html?ref_story_id=13720&amp;ref_type=1101&amp;ref_name=story
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01008352 0.09863775 0.8912787 ]
#
#
# Text: Gah, Comcast doubled our cable/internet bill w/out telling us, so we are quitting.  Can anyone suggest an affordable company in bay area?
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6285872  0.32392594 0.04748684]
#
#
# Text: Another early morn with the Duchess, although she hadn't managed to cross her legs this time
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.07935763 0.7872753  0.13336708]
#
#
# Text: @alexbigman you left without saying hi!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.35627916 0.54055303 0.1031678 ]
#
#
# Text: l want, but I can't sleep
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6229923  0.340826   0.03618168]
#
#
# Text: @TracyDowds When an Xbox shows those three red lights, it means it's dead and needs to be fixed for a month at Microsoft HQ.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7108708  0.25963742 0.0294918 ]
#
#
# Text: A king sized bed is nice but sad and lonely with no hubby, puppy, or kitty   I am over this whole conferenceing thing.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7191726  0.2193739  0.06145349]
#
#
# Text: im boredd. gah  i wish i could just sleep and get it over with but ive had toooo muchh cooooffffeeeeeeeee  bahaha
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.92332834 0.06382263 0.01284902]
#
#
# Text: @whyinthehell If I may butt in again.  I'm done being nosey.  sorry your conversation was just so interesting!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.07950346 0.22853246 0.6919641 ]
#
#
# Text: @smokey_robinson  you fell off my list...did I offend you?
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6631875  0.31561968 0.02119287]
#
#
# Text: 18 weeks till sisters home.. i missed her call, again! its the worst feeling in the world.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9639409  0.03148464 0.00457445]
#
#
# Text: gonna try to get some sleep in this hotel room
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.0939083  0.80616903 0.09992267]
#
#
# Text: @chimpytwit brilliant idea. just bring as much as you think you'll spend &amp; I'll swap you. bring a brolly
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01722246 0.23710264 0.74567485]
#
#
# Text: @SimoneKali Get me an autograph and shout out! You have to record it though. My computer is dead so I can't listen.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.62120813 0.31688708 0.06190478]
#
#
# Text: rt @KimKardashian Khloe just got fired from the Apprentice
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.46972573 0.5109094  0.019365  ]
#
#
# Text: in biology class. my lip hurts
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9252093  0.0655705  0.00922018]
#
#
# Text: Sorry for the next tweet...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5988408  0.36673352 0.03442569]
#
#
# Text: Grr not down to go to school today
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.625433   0.3440545  0.03051246]
#
#
# Text: @jennlopez I had to get an HD tivo and just got it set up tonight in order to get channels 40 - 59.
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.05040262 0.85758775 0.09200955]
#
#
# Text: @mouthsex i asked everyone how they were doing yesterday and not a single tweet back
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.55227304 0.40703666 0.04069033]
#
#
# Text: @adame ruddy money!! i like it!! still waiting here.... oh what a surprise... by state too?? hmmm....... seriously!!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.01893782 0.09039699 0.8906652 ]
#
#
# Text: @Kal_Penn I am so sad  Kutner was my favorite of the new team!!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.49777195 0.34702867 0.15519933]
#
#
# Text: @MarcusMims wow i didn't get an &quot;hello&quot; u suck
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.96973205 0.02615206 0.00411584]
#
#
# Text: bedtime, school tomorrow, and i still have no books  being broke suckssss
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9394043  0.05108152 0.00951422]
#
#
# Text: Seating here helping my baby with his papers...well he is forcing me too seat with him  im sleepy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.37839216 0.49222243 0.12938541]
#
#
# Text: Synching my contacts from my old mobile to iPhone. Import does not work well
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.91994876 0.07197838 0.00807288]
#
#
# Text: i can't concentrate
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.87596977 0.10830119 0.01572904]
#
#
# Text: I've just spent 1 hour to enter all the bureaucratic nonsense for March. What a waste of my time
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.91896385 0.06960461 0.01143154]
#
#
# Text: Nw more confused then ever!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.72187865 0.23493005 0.04319134]
#
#
# Text: Not feeling well again. Stupid migraine making my tummy upset.  and my whole body aches, shoot me now.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.97766453 0.01917046 0.00316506]
#
#
# Text: Reading Buyology before bedtime... great premise but only turning out to be an &quot;OK&quot; book - lots of info I already knew
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00698227 0.06441133 0.92860645]
#
#
# Text: Home! I really wana sleep, but due to wasting my free line in town I have an assignment to finish
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5933443  0.33891764 0.06773815]
#
#
# Text: @hellobebe I also send some updates in plurk but i upload photos on twitter!  you didnt see any of my updates on plurk? Zero?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.19394487 0.6991919  0.10686322]
#
#
# Text: omg... &quot;The Reader&quot; is making me
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.05464467 0.53439456 0.41096073]
#
#
# Text: @cloudpimps d'oh! At least you're getting a decent exchange rate at the moment, sterling is still getting flogged
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.10446059 0.43398806 0.4615513 ]
#
#
# Text: tried to download tweetdeck but it wont download
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.71349585 0.26462495 0.02187919]
#
#
# Text: There's an inch of snow on the ground (and counting). I'm worried about the poor flowers
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8728403  0.11221699 0.01494274]
#
#
# Text: @dweeman why aren't you a happy camper?
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.41982982 0.46400863 0.11616158]
#
#
# Text: @dkoenigs thanks man.  I'm so very grateful.  I feel unworthy of such attention, though, because I'm in this because of myself...
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.02644577 0.09035823 0.883196  ]
#
#
# Text: @t_wolfe  i miss u too. i'm totally comin back tho! Lastnight was sooooooo much fun!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00237304 0.01188959 0.9857373 ]
#
#
# Text: @sniffinglue ohhh. I love it. ps I'm sad we didn't get to hang out
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.11492348 0.15903169 0.7260448 ]
#
#
# Text: And somehow I still end up in this place
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.72936904 0.2431182  0.0275128 ]
#
#
# Text: @kisluvkis oh that is very sad, poor boy.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.92450887 0.06800171 0.00748946]
#
#
# Text: @JonathanRKnight @silver_tulip27 Um, that would be a hell no to the fugly poker dog pants on the cruise!  Hi Jonathan, sorry I missed you
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8332856  0.14028488 0.02642945]
#
#
# Text: I'm doing my homework. It's gosh darn hard!!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.68283147 0.2380251  0.07914346]
#
#
# Text: definitely no vacation for me...   http://plurk.com/p/mzygb
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.5752312  0.3587875  0.06598128]
#
#
# Text: 'study group extraordinare' about to leave campus...some of torts outline finished-good thing-but sleepy as h*#@...will be back@ 7am
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.02071455 0.31204334 0.6672421 ]
#
#
# Text: Why can't airfare go down? Or, why do I have to live in Texas!! I don't know if I'll be able to make it to Iowa.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.889397   0.10046495 0.01013804]
#
#
# Text: @j_stricko I found it pretty frustrating. stupid monkeys
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9655483  0.02961809 0.00483358]
#
#
# Text: @lenesha but Im not feeling well, mommy...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.842716   0.14679164 0.01049243]
#
#
# Text: @lovebscott Nope, I'm Right Along Wit' You!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.02237761 0.31335384 0.66426855]
#
#
# Text: so a murder? gotcha.  Cant believe it
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9162202  0.07649856 0.00728128]
#
#
# Text: @nbensalem i'm sitting at my house and i'm sooo not looking forward to my one class tomorrow.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9632709  0.03232442 0.00440467]
#
#
# Text: Ordered some maternity clothes online, which came today. I got something strange I didn't order, not in my size. And stuff is missing.
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.87210745 0.1166535  0.01123902]
#
#
# Text: @citizensheep
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.13364783 0.66320133 0.20315087]
#
#
# Text: @thesage1014 I wish I could! Gotta work though
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.2190856  0.5205994  0.26031494]
#
#
# Text: @SeaGhostdesigns what happened to you on Saturday? You didnt show up...
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.6467327  0.33500403 0.01826324]
#
#
# Text: @GirlsGoneChild
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.12911136 0.8189915  0.05189714]
#
#
# Text: Can't fall asleep
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.69534266 0.27376077 0.03089656]
#
#
# Text: I have mouth ulcer  so painful to talk and eat!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.97409576 0.02322617 0.00267804]
#
#
# Text: @danphelan Urgh, it was just the video, and they cut the Robots part!!!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.7914365  0.18524322 0.02332029]
#
#
# Text: my dog can't move anymore. praying that he will be okay
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.16897939 0.5045306  0.32649007]
#
#
# Text: @Kal_Penn you were pretty much my fave...not much reason to watch now
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.0481982  0.21948774 0.732314  ]
#
#
# Text: @Artistbabee but tht's annoying &amp;definitely not bitchy enough  he def broke like everything in me. he prolly doesn't even kno oct. 5!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.9542811  0.04021246 0.0055064 ]
#
#
# Text: @mileycyrus hahaha dont be like that one time in NY when you got 30 mins of sleep then got sick  love you!!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.05289246 0.15225527 0.7948522 ]
#
#
# Text: @normalguyguide I can't! I have so much to learn about WWI by tomorrow at noon!
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.19028878 0.36449435 0.44521686]
#
#
# Text: New Post!  http://tinyurl.com/cexkqy
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.00520834 0.5629063  0.4318853 ]
#
#
# Text: @graemearcher I am sad about Innocent selling out too!
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.8535129  0.13455057 0.01193654]
#
#
# Text: dang won't be able to get to any workshops run by web directions
# Predicted Sentiment: Negative 😠
# Sentiment Probabilities: [0.75372016 0.22971755 0.0165622 ]
#
#
# Text: @BenPritchett goodness me, how did you find me?? it's good to hear from you Ben! I still have your video game and book...I apologize
# Predicted Sentiment: Positive 😊
# Sentiment Probabilities: [0.00837933 0.09532071 0.8963    ]
#
#
# Text: Jap girls ? They're leaving!
# Predicted Sentiment: Neutral 😐
# Sentiment Probabilities: [0.42691585 0.5061733  0.0669108 ]
